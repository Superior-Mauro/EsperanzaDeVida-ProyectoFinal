# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('data_original_oms/data-text.csv')

# %%
data
# Out:
#                                               Indicator PUBLISH STATES  Year  \
# 0     Current health expenditure (CHE) per capita in...      Published  2002
# 1     Current health expenditure (CHE) per capita in...      Published  2003
# 2     Current health expenditure (CHE) per capita in...      Published  2004
# 3     Current health expenditure (CHE) per capita in...      Published  2005
# 4     Current health expenditure (CHE) per capita in...      Published  2006
# ...                                                 ...            ...   ...
# 3955  Current health expenditure (CHE) per capita in...      Published  2017
# 3956  Current health expenditure (CHE) per capita in...      Published  2018
# 3957  Current health expenditure (CHE) per capita in...      Published  2019
# 3958  Current health expenditure (CHE) per capita in...      Published  2020
# 3959  Current health expenditure (CHE) per capita in...      Published  2020
#
# ...

# %%
# Calcular el porcentaje de valores nulos por columna
porcentaje_nulos = (data.isnull().mean() * 100).round(2)

# Imprimir el resultado
print(porcentaje_nulos)
# Out:
# Indicator                             0.0
# PUBLISH STATES                        0.0
# Year                                  0.0
# WHO region                            0.0
# Countries, territories and areas      0.0
# Display Value                         0.0
# Numeric                               0.0
# Low                                 100.0
# High                                100.0
# StdErr                              100.0
# StdDev                              100.0
# Comments                            100.0
# dtype: float64
